# %%
from scipy import stats
import math
import csv
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print("This is my terminal cell")
# Out:
# This is my terminal cell

# %% [markdown]
# ## Step 1: Clean and merge 2016 data from weeks 1-7 only.

# %%
LA1 = pd.read_csv("Anon Week 1 Feedback - LA.csv")

# %%
LA1 = LA1.drop(columns=['Timestamp'])

# %%
LA1 = LA1.rename(index=str, columns={"How well are the tutorials paced?": "How would you rate the curriculum pace?"})

# %%
LA1.insert(0, 'Location', 'Los Angeles')
LA1.insert(1, 'Week', 'Week 1')
LA1
# Out:
#       Location    Week  \
# 0  Los Angeles  Week 1
# 1  Los Angeles  Week 1
# 2  Los Angeles  Week 1
# 3  Los Angeles  Week 1
# 4  Los Angeles  Week 1
# 5  Los Angeles  Week 1
# 6  Los Angeles  Week 1
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
# 5                                                  5
# 6                                                  5
#
#    How would you rate the curriculum pace?
# 0                                        4
# 1                                        4
# 2                                        4
# 3                                        4
# 4                                        5
# 5                                        4
# 6                                        3

# %%
NY1 = pd.read_csv("Anon Week 1 Feedback - NY.csv")

# %%
NY1 = NY1.drop(columns=['Timestamp'])

# %%
NY1 = NY1.rename(index = str, columns={'How well are the tutorials paced?': 'How would you rate the curriculum pace?', 'What track are you in?': 'Track'})

# %%
NY1.insert(0, 'Location', 'New York City')
NY1.insert(1, 'Week', 'Week 1')
NY1.head()
# Out:
#         Location    Week  Track  \
# 0  New York City  Week 1  Games
# 1  New York City  Week 1  Games
# 2  New York City  Week 1   Apps
# 3  New York City  Week 1  Intro
# 4  New York City  Week 1  Intro
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        5
# 1                                        3
# 2                                        3
# 3                                        3
# 4                                        4

# %%
SF1 = pd.read_csv("Anon Week 1 Feedback - SF.csv")

# %%
SF1 = SF1.drop(columns=['Timestamp'])

# %%
SF1 = SF1.rename(index=str, columns={'How well are the tutorials paced?': 'How would you rate the curriculum pace?', 'What track are you in?': 'Track'})

# %%
SF1.insert(0, 'Location', 'San Francisco')
SF1.insert(1, 'Week', 'Week 1')
SF1.head()
# Out:
#         Location    Week Track  \
# 0  San Francisco  Week 1  Apps
# 1  San Francisco  Week 1  Apps
# 2  San Francisco  Week 1  Apps
# 3  San Francisco  Week 1  Apps
# 4  San Francisco  Week 1  Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        2
# 1                                        3
# 2                                        4
# 3                                        5
# 4                                        2

# %%
SG1 = pd.read_csv("Anon Week 1 Feedback - Singapore.csv")

# %%
SG1 = SG1.drop(columns=['Timestamp'])

# %%
SG1 = SG1.rename(index=str, columns={'How well are the tutorials paced?': 'How would you rate the curriculum pace?'})

# %%
SG1.insert(0, 'Location', 'Singapore')
SG1.insert(1, 'Week', 'Week 1')
SG1.head()
# Out:
#     Location    Week  \
# 0  Singapore  Week 1
# 1  Singapore  Week 1
# 2  Singapore  Week 1
# 3  Singapore  Week 1
# 4  Singapore  Week 1
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        3
# 3                                        4
# 4                                        4

# %%
SV1 = pd.read_csv("Anon Week 1 Feedback - SV.csv")

# %%
SV1 = SV1.drop(columns=['Unnamed: 0'])

# %%
SV1 = SV1.rename(index=str, columns={'What track are you in?': 'Track', 'How well are the tutorials paced?': 'How would you rate the curriculum pace?'})

# %%
SV1.insert(0, 'Location', 'Sunnyvale')
SV1.insert(1, 'Week', 'Week 1')
SV1.head()
# Out:
#     Location    Week  Track  \
# 0  Sunnyvale  Week 1  Games
# 1  Sunnyvale  Week 1   Apps
# 2  Sunnyvale  Week 1   Apps
# 3  Sunnyvale  Week 1   Apps
# 4  Sunnyvale  Week 1   Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  2
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    How would you rate the curriculum pace?
# 0                                        4
# 1                                        4
# 2                                        3
# 3                                        5
# 4                                        3

# %%
LA2 = pd.read_csv("Anon Week 2 Feedback - LA.csv")

# %%
LA2 = LA2.drop(columns=['Timestamp'])

# %%
LA2 = LA2.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
LA2.insert(0, 'Location', 'Los Angeles')
LA2.insert(1, 'Week', 'Week 2')
LA2.head()
# Out:
#       Location    Week  \
# 0  Los Angeles  Week 2
# 1  Los Angeles  Week 2
# 2  Los Angeles  Week 2
# 3  Los Angeles  Week 2
# 4  Los Angeles  Week 2
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        2
# 1                                        3
# 2                                        4
# 3                                        3
# 4                                        3

# %%
NY2 = pd.read_csv("Anon Week 2 Feedback - NY.csv")

# %%
NY2 = NY2.drop(columns=['Timestamp'])

# %%
NY2 = NY2.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
NY2.insert(0, 'Location', 'New York City')
NY2.insert(1, 'Week', 'Week 2')
NY2.head()
# Out:
#         Location    Week  Track  \
# 0  New York City  Week 2   Apps
# 1  New York City  Week 2   Apps
# 2  New York City  Week 2  Games
# 3  New York City  Week 2  Games
# 4  New York City  Week 2   Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        2
# 1                                        4
# 2                                        5
# 3                                        3
# 4                                        3

# %%
SF2 = pd.read_csv("Anon Week 2 Feedback - SF.csv")

# %%
SF2 = SF2.drop(columns=['Timestamp'])

# %%
SF2 = SF2.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SF2.insert(0, 'Location', 'San Francisco')
SF2.insert(1, 'Week', 'Week 2')
SF2.head()
# Out:
#         Location    Week Track  \
# 0  San Francisco  Week 2  Apps
# 1  San Francisco  Week 2  Apps
# 2  San Francisco  Week 2  Apps
# 3  San Francisco  Week 2  Apps
# 4  San Francisco  Week 2  Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  2
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        2
# 2                                        3
# 3                                        3
# 4                                        2

# %%
SG2 = pd.read_csv("Anon Week 2 Feedback - SG.csv")

# %%
SG2 = SG2.drop(columns=['Timestamp'])

# %%
SG2 = SG2.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SG2.insert(0, 'Location', 'Singapore')
SG2.insert(1, 'Week', 'Week 2')
SG2.head()
# Out:
#     Location    Week  \
# 0  Singapore  Week 2
# 1  Singapore  Week 2
# 2  Singapore  Week 2
# 3  Singapore  Week 2
# 4  Singapore  Week 2
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        5
# 3                                        3
# 4                                        4

# %%
SV2 = pd.read_csv("Anon Week 2 Feedback - SV.csv")

# %%
SV2 = SV2.drop(columns=['Timestamp'])

# %%
SV2 = SV2.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SV2.insert(0, 'Location', 'Sunnyvale')
SV2.insert(1, 'Week', 'Week 2')
SV2.head()
# Out:
#     Location    Week Track  \
# 0  Sunnyvale  Week 2  Apps
# 1  Sunnyvale  Week 2  Apps
# 2  Sunnyvale  Week 2  Apps
# 3  Sunnyvale  Week 2  Apps
# 4  Sunnyvale  Week 2  Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    How would you rate the curriculum pace?
# 0                                        4
# 1                                        5
# 2                                        3
# 3                                        4
# 4                                        3

# %%
LA3 = pd.read_csv("Anon Week 3 Feedback - LA.csv")

# %%
LA3 = LA3.drop(columns='Timestamp')

# %%
LA3 = LA3.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
LA3.insert(0, 'Location', 'Los Angeles')
LA3.insert(1, 'Week', 'Week 3')
LA3.head()
# Out:
#       Location    Week  \
# 0  Los Angeles  Week 3
# 1  Los Angeles  Week 3
# 2  Los Angeles  Week 3
# 3  Los Angeles  Week 3
# 4  Los Angeles  Week 3
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        2
# 1                                        4
# 2                                        3
# 3                                        3
# 4                                        3

# %%
NY3 = pd.read_csv("Anon Week 3 Feedback - NY.csv")

# %%
NY3 = NY3.drop(columns=['Timestamp'])

# %%
NY3 = NY3.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?', 'What track are you in?': 'Track'})

# %%
NY3.insert(0, 'Location', 'New York City')
NY3.insert(1, 'Week', 'Week 3')
NY3.head()
# Out:
#         Location    Week  Track  \
# 0  New York City  Week 3   Apps
# 1  New York City  Week 3   Apps
# 2  New York City  Week 3  Intro
# 3  New York City  Week 3   Apps
# 4  New York City  Week 3   Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        3
# 3                                        3
# 4                                        2

# %%
SF3 = pd.read_csv("Anon Week 3 Feedback - SF.csv")

# %%
SF3 = SF3.drop(columns=['Timestamp'])

# %%
SF3 = SF3.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SF3.insert(0, 'Location', 'San Francisco')
SF3.insert(1, 'Week', 'Week 3')
SF3.head()
# Out:
#         Location    Week Track  \
# 0  San Francisco  Week 3  Apps
# 1  San Francisco  Week 3  Apps
# 2  San Francisco  Week 3  Apps
# 3  San Francisco  Week 3  Apps
# 4  San Francisco  Week 3  Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  5
# 2                                                  3
# 3                                                  1
# 4                                                  5
#
#    How would you rate the curriculum pace?
# 0                                        2
# 1                                        3
# 2                                        3
# 3                                        3
# 4                                        2

# %%
SG3 = pd.read_csv("Anon Week 3 Feedback - SG.csv")

# %%
SG3 = SG3.drop(columns=['Timestamp'])

# %%
SG3 = SG3.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SG3.insert(0, 'Location', 'Singapore')
SG3.insert(1, 'Week', 'Week 3')
SG3.head()
# Out:
#     Location    Week  \
# 0  Singapore  Week 3
# 1  Singapore  Week 3
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  5
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3

# %%
SV3 = pd.read_csv("Anon Week 3 Feedback - SV.csv")

# %%
SV3 = SV3.drop(columns=['Timestamp'])

# %%
SV3 = SV3.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SV3.insert(0, 'Location', 'Sunnyvale')
SV3.insert(1, 'Week', 'Week 3')
SV3.head()
# Out:
#     Location    Week  Track  \
# 0  Sunnyvale  Week 3  Games
# 1  Sunnyvale  Week 3   Apps
# 2  Sunnyvale  Week 3  Games
# 3  Sunnyvale  Week 3   Apps
# 4  Sunnyvale  Week 3   Apps
#
#   How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#   How would you rate the curriculum pace?
# 0                                       2
# 1                                       3
# 2                                       3
# 3                                       3
# 4                                       4

# %%
LA4 = pd.read_csv("Anon Week 4 Feedback - LA.csv")

# %%
LA4 = LA4.drop(columns=['Timestamp'])

# %%
LA4 = LA4.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
LA4.insert(0, 'Location', 'Los Angeles')
LA4.insert(1, 'Week', 'Week 4')
LA4.head()
# Out:
#       Location    Week  \
# 0  Los Angeles  Week 4
# 1  Los Angeles  Week 4
# 2  Los Angeles  Week 4
# 3  Los Angeles  Week 4
# 4  Los Angeles  Week 4
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  3
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        3
# 3                                        4
# 4                                        3

# %%
NY4 = pd.read_csv("Anon Week 4 Feedback - NY.csv")

# %%
NY4 = NY4.drop(columns=['Timestamp'])

# %%
NY4 = NY4.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
NY4.insert(0, 'Location', 'New York City')
NY4.insert(1, 'Week', 'Week 4')
NY4.head()
# Out:
#         Location    Week  Track  \
# 0  New York City  Week 4   Apps
# 1  New York City  Week 4   Apps
# 2  New York City  Week 4   Apps
# 3  New York City  Week 4   Apps
# 4  New York City  Week 4  Games
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        3
# 3                                        3
# 4                                        4

# %%
SF4 = pd.read_csv("Anon Week 4 Feedback - SF.csv")

# %%
SF4 = SF4.drop(columns=['Timestamp'])

# %%
SF4 = SF4.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SF4.insert(0, 'Location', 'San Francisco')
SF4.insert(1, 'Week', 'Week 4')
SF4.head()
# Out:
#         Location    Week Track  \
# 0  San Francisco  Week 4  Apps
# 1  San Francisco  Week 4  Apps
# 2  San Francisco  Week 4  Apps
# 3  San Francisco  Week 4  Apps
# 4  San Francisco  Week 4  Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        4
# 3                                        4
# 4                                        4

# %%
SG4 = pd.read_csv("Anon Week 4 Feedback - SG.csv")

# %%
SG4 = SG4.drop(columns=['Timestamp'])

# %%
SG4 = SG4.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SG4.insert(0, 'Location', 'Singapore')
SG4.insert(1, 'Week', 'Week 4')
SG4.head()
# Out:
#     Location    Week  \
# 0  Singapore  Week 4
# 1  Singapore  Week 4
# 2  Singapore  Week 4
# 3  Singapore  Week 4
# 4  Singapore  Week 4
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  3
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        4
# 2                                        3
# 3                                        3
# 4                                        4

# %%
SV4 = pd.read_csv("Anon Week 4 Feedback - SV.csv")

# %%
SV4 = SV4.drop(columns=['Timestamp'])

# %%
SV4 = SV4.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SV4.insert(0, 'Location', 'Sunnyvale')
SV4.insert(1, 'Week', 'Week 4')
SV4.head()
# Out:
#     Location    Week Track  \
# 0  Sunnyvale  Week 4  Apps
# 1  Sunnyvale  Week 4  Apps
# 2  Sunnyvale  Week 4  Apps
# 3  Sunnyvale  Week 4  Apps
# 4  Sunnyvale  Week 4  Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  2
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#    How would you rate the curriculum pace?
# 0                                        1
# 1                                        3
# 2                                        4
# 3                                        3
# 4                                        3

# %%
HK1 = pd.read_csv("Anon Week 5 Feedback - HK.csv")

# %%
HK1 = HK1.drop(columns=['Timestamp'])

# %%
HK1 = HK1.rename(index=str, columns={'How well are the tutorials paced?': 'How would you rate the curriculum pace?'})

# %%
HK1.insert(0, 'Location', 'Hong Kong')
HK1.insert(1, 'Week', 'Week 5')
HK1.head()
# Out:
#     Location    Week  \
# 0  Hong Kong  Week 5
# 1  Hong Kong  Week 5
# 2  Hong Kong  Week 5
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  5
# 2                                                  5
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        3

# %%
LA5 = pd.read_csv("Anon Week 5 Feedback - LA.csv")

# %%
LA5 = LA5.drop(columns=['Timestamp'])

# %%
LA5 = LA5.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
LA5.insert(0, 'Location', 'Los Angeles')
LA5.insert(1, 'Week', 'Week 5')
LA5.head()
# Out:
#       Location    Week  Track  \
# 0  Los Angeles  Week 5  Games
# 1  Los Angeles  Week 5  Intro
# 2  Los Angeles  Week 5  Intro
# 3  Los Angeles  Week 5  Games
# 4  Los Angeles  Week 5  Intro
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  4
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        2
# 1                                        3
# 2                                        3
# 3                                        3
# 4                                        3

# %%
NY5 = pd.read_csv("Anon Week 5 Feedback - NY.csv")

# %%
NY5 = NY5.drop(columns=['Timestamp'])

# %%
NY5 = NY5.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
NY5.insert(0, 'Location', 'New York City')
NY5.insert(1, 'Week', 'Week 5')
NY5.head()
# Out:
#         Location    Week Track  \
# 0  New York City  Week 5  Apps
# 1  New York City  Week 5  Apps
# 2  New York City  Week 5  Apps
# 3  New York City  Week 5  Apps
# 4  New York City  Week 5  Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#    How would you rate the curriculum pace?
# 0                                        5
# 1                                        3
# 2                                        3
# 3                                        3
# 4                                        3

# %%
SF5 = pd.read_csv("Anon Week 5 Feedback - SF.csv")

# %%
SF5 = SF5.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SF5.insert(0, 'Location', 'San Francisco')
SF5.insert(1, 'Week', 'Week 5')
SF5.head()
# Out:
#         Location    Week Track  \
# 0  San Francisco  Week 5  Apps
# 1  San Francisco  Week 5  Apps
# 2  San Francisco  Week 5  Apps
# 3  San Francisco  Week 5  Apps
# 4  San Francisco  Week 5  Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        3
# 3                                        4
# 4                                        3

# %%
SG5 = pd.read_csv("Anon Week 5 Feedback - SG.csv")

# %%
SG5 = SG5.drop(columns=['Timestamp'])

# %%
SG5 = SG5.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SG5.insert(0, 'Location', 'Singapore')
SG5.insert(1, 'Week', 'Week 5')
SG5.head()
# Out:
#     Location    Week  \
# 0  Singapore  Week 5
# 1  Singapore  Week 5
# 2  Singapore  Week 5
# 3  Singapore  Week 5
# 4  Singapore  Week 5
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        4
# 3                                        3
# 4                                        4

# %%
SV5 = pd.read_csv("Anon Week 5 Feedback - SV.csv")

# %%
SV5 = SV5.drop(columns=['Timestamp'])

# %%
SV5 = SV5.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SV5.insert(0, 'Location', 'Sunnyvale')
SV5.insert(1, 'Week', 'Week 5')
SV5.head()
# Out:
#     Location    Week  Track  \
# 0  Sunnyvale  Week 5   Apps
# 1  Sunnyvale  Week 5   Apps
# 2  Sunnyvale  Week 5   Apps
# 3  Sunnyvale  Week 5   Apps
# 4  Sunnyvale  Week 5  Games
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  5
# 2                                                  3
# 3                                                  2
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        3
# 3                                        3
# 4                                        3

# %%
HK2 = pd.read_csv("Anon Week 6 Feedback - HK.csv")

# %%
HK2 = HK2.drop(columns=['Timestamp'])

# %%
HK2 = HK2.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
HK2.insert(0, 'Location', 'Hong Kong')
HK2.insert(1, 'Week', 'Week 6')
HK2.head()
# Out:
#     Location    Week  \
# 0  Hong Kong  Week 6
# 1  Hong Kong  Week 6
# 2  Hong Kong  Week 6
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  4
# 2                                                  5
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        3

# %%
LA6 = pd.read_csv("Anon Week 6 Feedback - LA.csv")

# %%
LA6 = LA6.drop(columns=['Timestamp'])

# %%
LA6 = LA6.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
LA6.insert(0, 'Location', 'Los Angeles')
LA6.insert(1, 'Week', 'Week 6')
LA6.head()
# Out:
#       Location    Week  Track  \
# 0  Los Angeles  Week 6  Games
# 1  Los Angeles  Week 6  Intro
# 2  Los Angeles  Week 6  Games
# 3  Los Angeles  Week 6  Games
# 4  Los Angeles  Week 6  Intro
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  5
# 2                                                  3
# 3                                                  1
# 4                                                  5
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        1
# 3                                        3
# 4                                        3

# %%
NY6 = pd.read_csv("Anon Week 6 Feedback - NY.csv")

# %%
NY6 = NY6.drop(columns=['Timestamp'])

# %%
NY6 = NY6.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
NY6.insert(0, 'Location', 'New York City')
NY6.insert(1, 'Week', 'Week 6')
NY6.head()
# Out:
#         Location    Week  Track  \
# 0  New York City  Week 6   Apps
# 1  New York City  Week 6   Apps
# 2  New York City  Week 6   Apps
# 3  New York City  Week 6   Apps
# 4  New York City  Week 6  Games
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  2
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    How would you rate the curriculum pace?
# 0                                        2
# 1                                        3
# 2                                        4
# 3                                        3
# 4                                        3

# %%
SF6 = pd.read_csv("Anon Week 6 Feedback - SF.csv")

# %%
SF6 = SF6.drop(columns=['Timestamp'])

# %%
SF6 = SF6.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SF6.insert(0, 'Location', 'San Francisco')
SF6.insert(1, 'Week', 'Week 6')
SF6.head()
# Out:
#         Location    Week Track  \
# 0  San Francisco  Week 6  Apps
# 1  San Francisco  Week 6  Apps
# 2  San Francisco  Week 6  Apps
# 3  San Francisco  Week 6  Apps
# 4  San Francisco  Week 6  Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  3
# 2                                                  2
# 3                                                  4
# 4                                                  3
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        4
# 2                                        3
# 3                                        3
# 4                                        4

# %%
SG6 = pd.read_csv("Anon Week 6 Feedback - SG.csv")

# %%
SG6 = SG6.drop(columns=['Timestamp'])

# %%
SG6 = SG6.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SG6.insert(0, 'Location', 'Singapore')
SG6.insert(1, 'Week', 'Week 6')
SG6.head()
# Out:
#     Location    Week  \
# 0  Singapore  Week 6
# 1  Singapore  Week 6
# 2  Singapore  Week 6
# 3  Singapore  Week 6
# 4  Singapore  Week 6
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  3
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        5
# 2                                        3
# 3                                        3
# 4                                        5

# %%
SV6 = pd.read_csv("Anon Week 6 Feedback - SV.csv")

# %%
SV6 = SV6.drop(columns=['Timestamp'])

# %%
SV6 = SV6.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SV6.insert(0, 'Location', 'Sunnyvale')
SV6.insert(1, 'Week', 'Week 6')
SV6.head()
# Out:
#     Location    Week Track  \
# 0  Sunnyvale  Week 6  Apps
# 1  Sunnyvale  Week 6  Apps
# 2  Sunnyvale  Week 6  Apps
# 3  Sunnyvale  Week 6  Apps
# 4  Sunnyvale  Week 6  Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  3
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        4
# 3                                        3
# 4                                        3

# %%
Taipei1 = pd.read_csv("Anon Week 6 Feedback - Taipei.csv")

# %%
Taipei1 = Taipei1.drop(columns=['Timestamp'])

# %%
Taipei1 = Taipei1.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
Taipei1.insert(0, 'Location', 'Taipei')
Taipei1.insert(1, 'Week', 'Week 6')
Taipei1.head()
# Out:
#   Location    Week  \
# 0   Taipei  Week 6
# 1   Taipei  Week 6
# 2   Taipei  Week 6
# 3   Taipei  Week 6
# 4   Taipei  Week 6
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        4
# 2                                        3
# 3                                        3
# 4                                        3

# %%
Tokyo1 = pd.read_csv("Anon Week 6 Feedback - Tokyo.csv")

# %%
Tokyo1 = Tokyo1.drop(columns=['Timestamp'])

# %%
Tokyo1 = Tokyo1.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
Tokyo1.insert(0, 'Location', 'Tokyo')
Tokyo1.insert(1, 'Week', 'Week 6')
Tokyo1.head()
# Out:
#   Location    Week  \
# 0    Tokyo  Week 6
# 1    Tokyo  Week 6
# 2    Tokyo  Week 6
# 3    Tokyo  Week 6
# 4    Tokyo  Week 6
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#    How would you rate the curriculum pace?
# 0                                        4
# 1                                        3
# 2                                        1
# 3                                        2
# 4                                        4

# %%
LA7 = pd.read_csv("Anon Week 7 Feedback - LA.csv")

# %%
LA7 = LA7.drop(columns=['Timestamp'])

# %%
LA7 = LA7.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
LA7.insert(0, 'Location', 'Los Angeles')
LA7.insert(1, 'Week', 'Week 7')
LA7.head()
# Out:
#       Location    Week  Track  \
# 0  Los Angeles  Week 7  Intro
# 1  Los Angeles  Week 7  Intro
# 2  Los Angeles  Week 7  Games
# 3  Los Angeles  Week 7  Intro
# 4  Los Angeles  Week 7  Games
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        2
# 1                                        3
# 2                                        2
# 3                                        3
# 4                                        3

# %%
NY7 = pd.read_csv("Anon Week 7 Feedback - NY.csv")

# %%
NY7 = NY7.drop(columns=['Timestamp'])

# %%
NY7 = NY7.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
NY7.insert(0, 'Location', 'New York City')
NY7.insert(1, 'Week', 'Week 7')
NY7.head()
# Out:
#         Location    Week  Track  \
# 0  New York City  Week 7   Apps
# 1  New York City  Week 7   Apps
# 2  New York City  Week 7  Games
# 3  New York City  Week 7  Games
# 4  New York City  Week 7   Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        3
# 3                                        3
# 4                                        3

# %%
SF7 = pd.read_csv("Anon Week 7 Feedback - SF.csv")

# %%
SF7 = SF7.drop(columns=['Timestamp'])

# %%
SF7 = SF7.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SF7.insert(0, 'Location', 'San Francisco')
SF7.insert(1, 'Week', 'Week 7')
SF7.head()
# Out:
#         Location    Week Track  \
# 0  San Francisco  Week 7  Apps
# 1  San Francisco  Week 7  Apps
# 2  San Francisco  Week 7  Apps
# 3  San Francisco  Week 7  Apps
# 4  San Francisco  Week 7  Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  3
# 2                                                  5
# 3                                                  5
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        5
# 1                                        3
# 2                                        3
# 3                                        4
# 4                                        3

# %%
SV7 = pd.read_csv("Anon Week 7 Feedback - SV.csv")

# %%
SV7 = SV7.drop(columns='Timestamp')

# %%
SV7 = SV7.rename(index=str, columns={'What track are you in?': 'Track', 'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
SV7.insert(0, 'Location', 'Sunnyvale')
SV7.insert(1, 'Week', 'Week 7')
SV7.head()
# Out:
#     Location    Week Track  \
# 0  Sunnyvale  Week 7  Apps
# 1  Sunnyvale  Week 7  Apps
# 2  Sunnyvale  Week 7  Apps
# 3  Sunnyvale  Week 7  Apps
# 4  Sunnyvale  Week 7  Apps
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  5
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        3
# 3                                        3
# 4                                        3

# %%
Taipei2 = pd.read_csv("Anon Week 7 Feedback - Taipei.csv")

# %%
Taipei2 = Taipei2.drop(columns=['Timestamp'])

# %%
Taipei2 = Taipei2.rename(index=str, columns={'How well is the schedule paced?': 'How would you rate the curriculum pace?'})

# %%
Taipei2.insert(0, 'Location', 'Taipei')
Taipei2.insert(1, 'Week', 'Week 7')
Taipei2.head()
# Out:
#   Location    Week  \
# 0   Taipei  Week 7
# 1   Taipei  Week 7
# 2   Taipei  Week 7
# 3   Taipei  Week 7
# 4   Taipei  Week 7
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#    How would you rate the curriculum pace?
# 0                                        3
# 1                                        3
# 2                                        3
# 3                                        4
# 4                                        4

# %%
first7of2016 = [LA1, NY1, SF1, SG1, SV1, LA2, NY2, SF2, SG2, SV2, LA3, NY3, SF3, SG3, SV3, LA4, NY4, SF4, SG4, SV4, HK1, LA5, NY5, SF5, SG5, SV5, HK2, LA6, NY6, SF6, SG6, SV6, Taipei1, Tokyo1, LA7, NY7, SF7, SV7, Taipei2]
f_results = pd.concat(first7of2016, sort=True)
f_results.head()
# Out:
#   How would you rate the curriculum pace?  \
# 0                                       4
# 1                                       4
# 2                                       4
# 3                                       4
# 4                                       5
#
#   How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#       Location Track    Week
# 0  Los Angeles   NaN  Week 1
# 1  Los Angeles   NaN  Week 1
# 2  Los Angeles   NaN  Week 1
# 3  Los Angeles   NaN  Week 1
# 4  Los Angeles   NaN  Week 1

# %% [markdown]
# ## Step 2: Clean the 2016 data from week 8.

# %%
Weak8 = pd.read_csv("Week 8 Feedback (2016, incomplete) - results.csv")

# %%
Weak8.head()
# Out:
#                                   #  \
# 0  00b836bda84e6bdbe780af97e249e59f
# 1  39dde6dc0e1e375845d756fc7e39fc5f
# 2  5e56b9de91670b308cb98dd2848b8739
# 3  641081d05785b47a0f17448625da0d49
# 4  c29bdd4f5678d78b450f4494e0f53c8c
#
#    How likely is it that you would recommend the Make School Summer Academy to a friend?  \
# 0                                                 10
# 1                                                 10
# 2                                                 10
# 3                                                  9
# 4                                                  3
#
#         location                track Start Date (UTC) Submit Date (UTC)  \
# 0       New York           summerApps      9/7/16 1:03       9/7/16 1:04
# 1  San Francisco          summerIntro      9/7/16 1:03       9/7/16 1:04
# 2       New York          summerIntro      9/7/16 1:03       9/7/16 1:05
# 3      Sunnyvale  summerApps (4-week)      9/7/16 1:04       9/7/16 1:06
# 4  San Francisco          summerIntro      9/7/16 1:04       9/7/16 1:11
#
#    Network ID
# 0  3212b7a834
# 1  f4954355aa
# 2  3d69ca289b
# 3  261608f95d
# 4  d6672ddf6f

# %%
Y2017 = pd.read_csv("Student Feedback Surveys-Superview.csv")
Y2017
# Perhaps: "Just right" = promoter; "A little too...." = passive; "Way too...." = detractor
# DO NOT convert "Schedule Pacing" to numbers - simply ADD A COLUMN based on the answers there that
# labels them as promoters, passives, detractors
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-91-eee8465d9192> in <module>
# ----> 1 Y2017 = pd.read_csv("Student Feedback Surveys-Superview.csv")
#       2 Y2017
#       3 # Perhaps: "Just right" = promoter; "A little too...." = passive; "Way too...." = detractor
#       4 # DO NOT convert "Schedule Pacing" to numbers - simply ADD A COLUMN based on the answers there that
#       5 # labels them as promoters, passives, detractors
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'Student Feedback Surveys-Superview.csv' does not exist

# %%
# Ideas: One set with ONLY timestamps, summer academy ratings, pacings
#         One set with ONLY track, summer academy ratings, pacings
#       One set for EVERY CITY, with the YEAR appended
# Q1: What is the average overall satisfaction with the Summer Academy?
# Q2: Which weeks on both years yield the most promoters?
# Q3: Of those promoters, how many were on the intro track?
# Q4: And how many were on the app track?
# Q5: And how many were on the games track?
# Q6: Which weeks on both years yield the most detractors?
# Q7: Of those detractors, how many were on the intro track?
# Q8: And how many were on the app track?
# Q9: And how many were on the games track?

# %%
frames = [LA1, NY1, SF1, SG1, SV1, LA2, NY2, SF2, SG2, SV2, LA3, NY3, SF3, SG3, SV3, LA4, NY4, SF4, SG4, SV4, HK1, LA5, NY5, SF5, SG5, SV5, HK2, LA6, NY6, SF6, SG6, SV6, Taipei1, Tokyo1, LA7, NY7, SF7, SV7, Taipei2, Weak8, Y2017]
result = pd.concat(frames, sort=True)
result
# Out:
#         #  \
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# ...   ...
# 1423  NaN
# 1424  NaN
# 1425  NaN
# 1426  NaN
# 1427  NaN
# 1428  NaN
# 1429  NaN
# 1430  NaN
# 1431  NaN
# 1432  NaN
# 1433  NaN
# 1434  NaN
# 1435  NaN
# 1436  NaN
# 1437  NaN
# 1438  NaN
# 1439  NaN
# 1440  NaN
# 1441  NaN
# 1442  NaN
# 1443  NaN
# 1444  NaN
# 1445  NaN
# 1446  NaN
# 1447  NaN
# 1448  NaN
# 1449  NaN
# 1450  NaN
# 1451  NaN
# 1452  NaN
#
#       How likely is it that you would recommend the Make School Summer Academy to a friend?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# ...                                                 ...
# 1423                                                NaN
# 1424                                                NaN
# 1425                                                NaN
# 1426                                                NaN
# 1427                                                NaN
# 1428                                                NaN
# 1429                                                NaN
# 1430                                                NaN
# 1431                                                NaN
# 1432                                                NaN
# 1433                                                NaN
# 1434                                                NaN
# 1435                                                NaN
# 1436                                                NaN
# 1437                                                NaN
# 1438                                                NaN
# 1439                                                NaN
# 1440                                                NaN
# 1441                                                NaN
# 1442                                                NaN
# 1443                                                NaN
# 1444                                                NaN
# 1445                                                NaN
# 1446                                                NaN
# 1447                                                NaN
# 1448                                                NaN
# 1449                                                NaN
# 1450                                                NaN
# 1451                                                NaN
# 1452                                                NaN
#
#       How well are the tutorials paced? How well is the schedule paced?  \
# 0                                   4.0                             NaN
# 1                                   4.0                             NaN
# 2                                   4.0                             NaN
# 3                                   4.0                             NaN
# 4                                   5.0                             NaN
# 5                                   4.0                             NaN
# 6                                   3.0                             NaN
# 0                                   5.0                             NaN
# 1                                   3.0                             NaN
# 2                                   3.0                             NaN
# 3                                   3.0                             NaN
# 4                                   4.0                             NaN
# 5                                   4.0                             NaN
# 6                                   4.0                             NaN
# 7                                   4.0                             NaN
# 8                                   4.0                             NaN
# 9                                   3.0                             NaN
# 10                                  3.0                             NaN
# 11                                  4.0                             NaN
# 12                                  4.0                             NaN
# 13                                  4.0                             NaN
# 14                                  4.0                             NaN
# 15                                  3.0                             NaN
# 16                                  4.0                             NaN
# 17                                  2.0                             NaN
# 18                                  3.0                             NaN
# 19                                  4.0                             NaN
# 20                                  4.0                             NaN
# 21                                  3.0                             NaN
# 22                                  3.0                             NaN
# ...                                 ...                             ...
# 1423                                NaN                             NaN
# 1424                                NaN                             NaN
# 1425                                NaN                             NaN
# 1426                                NaN                             NaN
# 1427                                NaN                             NaN
# 1428                                NaN                             NaN
# 1429                                NaN                             NaN
# 1430                                NaN                             NaN
# 1431                                NaN                             NaN
# 1432                                NaN                             NaN
# 1433                                NaN                             NaN
# 1434                                NaN                             NaN
# 1435                                NaN                             NaN
# 1436                                NaN                             NaN
# 1437                                NaN                             NaN
# 1438                                NaN                             NaN
# 1439                                NaN                             NaN
# 1440                                NaN                             NaN
# 1441                                NaN                             NaN
# 1442                                NaN                             NaN
# 1443                                NaN                             NaN
# 1444                                NaN                             NaN
# 1445                                NaN                             NaN
# 1446                                NaN                             NaN
# 1447                                NaN                             NaN
# 1448                                NaN                             NaN
# 1449                                NaN                             NaN
# 1450                                NaN                             NaN
# 1451                                NaN                             NaN
# 1452                                NaN                             NaN
#
#      How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                     3
# 1                                                     4
# 2                                                     4
# 3                                                     4
# 4                                                     4
# 5                                                     5
# 6                                                     5
# 0                                                     3
# 1                                                     3
# 2                                                     3
# 3                                                     4
# 4                                                     4
# 5                                                     4
# 6                                                     4
# 7                                                     4
# 8                                                     4
# 9                                                     4
# 10                                                    4
# 11                                                    4
# 12                                                    4
# 13                                                    4
# 14                                                    4
# 15                                                    4
# 16                                                    4
# 17                                                    4
# 18                                                    4
# 19                                                    4
# 20                                                    4
# 21                                                    4
# 22                                                    5
# ...                                                 ...
# 1423                                                NaN
# 1424                                                NaN
# 1425                                                NaN
# 1426                                                NaN
# 1427                                                NaN
# 1428                                                NaN
# 1429                                                NaN
# 1430                                                NaN
# 1431                                                NaN
# 1432                                                NaN
# 1433                                                NaN
# 1434                                                NaN
# 1435                                                NaN
# 1436                                                NaN
# 1437                                                NaN
# 1438                                                NaN
# 1439                                                NaN
# 1440                                                NaN
# 1441                                                NaN
# 1442                                                NaN
# 1443                                                NaN
# 1444                                                NaN
# 1445                                                NaN
# 1446                                                NaN
# 1447                                                NaN
# 1448                                                NaN
# 1449                                                NaN
# 1450                                                NaN
# 1451                                                NaN
# 1452                                                NaN
#
#           ID       Location Network ID Rating (Num)    Schedule Pacing  \
# 0        NaN            NaN        NaN          NaN                NaN
# 1        NaN            NaN        NaN          NaN                NaN
# 2        NaN            NaN        NaN          NaN                NaN
# 3        NaN            NaN        NaN          NaN                NaN
# 4        NaN            NaN        NaN          NaN                NaN
# 5        NaN            NaN        NaN          NaN                NaN
# 6        NaN            NaN        NaN          NaN                NaN
# 0        NaN            NaN        NaN          NaN                NaN
# 1        NaN            NaN        NaN          NaN                NaN
# 2        NaN            NaN        NaN          NaN                NaN
# 3        NaN            NaN        NaN          NaN                NaN
# 4        NaN            NaN        NaN          NaN                NaN
# 5        NaN            NaN        NaN          NaN                NaN
# 6        NaN            NaN        NaN          NaN                NaN
# 7        NaN            NaN        NaN          NaN                NaN
# 8        NaN            NaN        NaN          NaN                NaN
# 9        NaN            NaN        NaN          NaN                NaN
# 10       NaN            NaN        NaN          NaN                NaN
# 11       NaN            NaN        NaN          NaN                NaN
# 12       NaN            NaN        NaN          NaN                NaN
# 13       NaN            NaN        NaN          NaN                NaN
# 14       NaN            NaN        NaN          NaN                NaN
# 15       NaN            NaN        NaN          NaN                NaN
# 16       NaN            NaN        NaN          NaN                NaN
# 17       NaN            NaN        NaN          NaN                NaN
# 18       NaN            NaN        NaN          NaN                NaN
# 19       NaN            NaN        NaN          NaN                NaN
# 20       NaN            NaN        NaN          NaN                NaN
# 21       NaN            NaN        NaN          NaN                NaN
# 22       NaN            NaN        NaN          NaN                NaN
# ...      ...            ...        ...          ...                ...
# 1423  1470.0  New York City        NaN           10         Just right
# 1424  1471.0  New York City        NaN            8         Just right
# 1425  1472.0  New York City        NaN            9         Just right
# 1426  1473.0  New York City        NaN           10         Just right
# 1427  1474.0  New York City        NaN            9         Just right
# 1428  1475.0  New York City        NaN            9         Just right
# 1429  1476.0  New York City        NaN            8  A little too fast
# 1430  1477.0  New York City        NaN           10         Just right
# 1431  1478.0  New York City        NaN           10         Just right
# 1432  1479.0  New York City        NaN            9         Just right
# 1433  1480.0  New York City        NaN            9         Just right
# 1434  1481.0  New York City        NaN           10         Just right
# 1435  1482.0  New York City        NaN            8         Just right
# 1436  1483.0  New York City        NaN            7  A little too fast
# 1437  1484.0  New York City        NaN            7       Way too fast
# 1438  1485.0  New York City        NaN            7         Just right
# 1439  1486.0  New York City        NaN            9         Just right
# 1440  1487.0  New York City        NaN            8         Just right
# 1441  1488.0  New York City        NaN            7         Just right
# 1442  1489.0  New York City        NaN           10         Just right
# 1443  1490.0  New York City        NaN           10         Just right
# 1444  1491.0  New York City        NaN            9  A little too fast
# 1445  1492.0  New York City        NaN            9         Just right
# 1446  1493.0  New York City        NaN            3         Just right
# 1447  1494.0  New York City        NaN           10         Just right
# 1448  1495.0  New York City        NaN           10         Just right
# 1449  1496.0  New York City        NaN            8         Just right
# 1450  1497.0  New York City        NaN           10         Just right
# 1451  1498.0  New York City        NaN            1  A little too slow
# 1452  1499.0  New York City        NaN            8         Just right
#
#      Start Date (UTC) Submit Date (UTC)           Timestamp            Track  \
# 0                 NaN               NaN  6/23/2016 15:55:12              NaN
# 1                 NaN               NaN  6/23/2016 16:14:04              NaN
# 2                 NaN               NaN   6/24/2016 0:18:42              NaN
# 3                 NaN               NaN   6/24/2016 6:59:42              NaN
# 4                 NaN               NaN   6/24/2016 9:40:16              NaN
# 5                 NaN               NaN  6/23/2016 22:07:29              NaN
# 6                 NaN               NaN   6/24/2016 9:34:14              NaN
# 0                 NaN               NaN   6/24/2016 7:03:34              NaN
# 1                 NaN               NaN   6/24/2016 7:10:22              NaN
# 2                 NaN               NaN   6/24/2016 7:03:41              NaN
# 3                 NaN               NaN   6/24/2016 7:04:59              NaN
# 4                 NaN               NaN   6/24/2016 7:07:02              NaN
# 5                 NaN               NaN   6/24/2016 7:08:41              NaN
# 6                 NaN               NaN   6/24/2016 7:09:30              NaN
# 7                 NaN               NaN   6/24/2016 7:01:03              NaN
# 8                 NaN               NaN   6/24/2016 7:02:43              NaN
# 9                 NaN               NaN   6/24/2016 7:03:48              NaN
# 10                NaN               NaN   6/24/2016 7:06:04              NaN
# 11                NaN               NaN   6/24/2016 7:06:24              NaN
# 12                NaN               NaN   6/24/2016 7:01:19              NaN
# 13                NaN               NaN   6/24/2016 7:01:29              NaN
# 14                NaN               NaN   6/24/2016 7:02:20              NaN
# 15                NaN               NaN   6/24/2016 7:03:24              NaN
# 16                NaN               NaN   6/24/2016 7:03:25              NaN
# 17                NaN               NaN   6/24/2016 7:03:58              NaN
# 18                NaN               NaN   6/24/2016 7:06:59              NaN
# 19                NaN               NaN   6/24/2016 7:07:06              NaN
# 20                NaN               NaN   6/24/2016 7:08:37              NaN
# 21                NaN               NaN   6/24/2016 7:08:51              NaN
# 22                NaN               NaN   6/24/2016 7:01:55              NaN
# ...               ...               ...                 ...              ...
# 1423              NaN               NaN                 NaN            Games
# 1424              NaN               NaN                 NaN             Apps
# 1425              NaN               NaN                 NaN            Games
# 1426              NaN               NaN                 NaN  Games, Explorer
# 1427              NaN               NaN                 NaN            Games
# 1428              NaN               NaN                 NaN             Apps
# 1429              NaN               NaN                 NaN             Apps
# 1430              NaN               NaN                 NaN            Games
# 1431              NaN               NaN                 NaN             Apps
# 1432              NaN               NaN                 NaN            Games
# 1433              NaN               NaN                 NaN             Apps
# 1434              NaN               NaN                 NaN             Apps
# 1435              NaN               NaN                 NaN             Apps
# 1436              NaN               NaN                 NaN             Apps
# 1437              NaN               NaN                 NaN   Apps, Explorer
# 1438              NaN               NaN                 NaN             Apps
# 1439              NaN               NaN                 NaN             Apps
# 1440              NaN               NaN                 NaN             Apps
# 1441              NaN               NaN                 NaN  Games, Explorer
# 1442              NaN               NaN                 NaN   Apps, Explorer
# 1443              NaN               NaN                 NaN   Apps, Explorer
# 1444              NaN               NaN                 NaN            Games
# 1445              NaN               NaN                 NaN             Apps
# 1446              NaN               NaN                 NaN             Apps
# 1447              NaN               NaN                 NaN  Games, Explorer
# 1448              NaN               NaN                 NaN   Apps, Explorer
# 1449              NaN               NaN                 NaN   Apps, Explorer
# 1450              NaN               NaN                 NaN             Apps
# 1451              NaN               NaN                 NaN   Apps, Explorer
# 1452              NaN               NaN                 NaN             Apps
#
#      Unnamed: 0    Week What track are you in? location track
# 0           NaN     NaN                    NaN      NaN   NaN
# 1           NaN     NaN                    NaN      NaN   NaN
# 2           NaN     NaN                    NaN      NaN   NaN
# 3           NaN     NaN                    NaN      NaN   NaN
# 4           NaN     NaN                    NaN      NaN   NaN
# 5           NaN     NaN                    NaN      NaN   NaN
# 6           NaN     NaN                    NaN      NaN   NaN
# 0           NaN     NaN                  Games      NaN   NaN
# 1           NaN     NaN                  Games      NaN   NaN
# 2           NaN     NaN                   Apps      NaN   NaN
# 3           NaN     NaN                  Intro      NaN   NaN
# 4           NaN     NaN                  Intro      NaN   NaN
# 5           NaN     NaN                  Intro      NaN   NaN
# 6           NaN     NaN                  Intro      NaN   NaN
# 7           NaN     NaN                  Games      NaN   NaN
# 8           NaN     NaN                  Games      NaN   NaN
# 9           NaN     NaN                  Games      NaN   NaN
# 10          NaN     NaN                  Games      NaN   NaN
# 11          NaN     NaN                  Games      NaN   NaN
# 12          NaN     NaN                   Apps      NaN   NaN
# 13          NaN     NaN                   Apps      NaN   NaN
# 14          NaN     NaN                   Apps      NaN   NaN
# 15          NaN     NaN                   Apps      NaN   NaN
# 16          NaN     NaN                   Apps      NaN   NaN
# 17          NaN     NaN                   Apps      NaN   NaN
# 18          NaN     NaN                   Apps      NaN   NaN
# 19          NaN     NaN                   Apps      NaN   NaN
# 20          NaN     NaN                   Apps      NaN   NaN
# 21          NaN     NaN                   Apps      NaN   NaN
# 22          NaN     NaN                  Intro      NaN   NaN
# ...         ...     ...                    ...      ...   ...
# 1423        NaN  Week 7                    NaN      NaN   NaN
# 1424        NaN  Week 7                    NaN      NaN   NaN
# 1425        NaN  Week 7                    NaN      NaN   NaN
# 1426        NaN  Week 7                    NaN      NaN   NaN
# 1427        NaN  Week 7                    NaN      NaN   NaN
# 1428        NaN  Week 7                    NaN      NaN   NaN
# 1429        NaN  Week 7                    NaN      NaN   NaN
# 1430        NaN  Week 7                    NaN      NaN   NaN
# 1431        NaN  Week 7                    NaN      NaN   NaN
# 1432        NaN  Week 7                    NaN      NaN   NaN
# 1433        NaN  Week 7                    NaN      NaN   NaN
# 1434        NaN  Week 7                    NaN      NaN   NaN
# 1435        NaN  Week 7                    NaN      NaN   NaN
# 1436        NaN  Week 7                    NaN      NaN   NaN
# 1437        NaN  Week 7                    NaN      NaN   NaN
# 1438        NaN  Week 7                    NaN      NaN   NaN
# 1439        NaN  Week 7                    NaN      NaN   NaN
# 1440        NaN  Week 7                    NaN      NaN   NaN
# 1441        NaN  Week 7                    NaN      NaN   NaN
# 1442        NaN  Week 7                    NaN      NaN   NaN
# 1443        NaN  Week 7                    NaN      NaN   NaN
# 1444        NaN  Week 7                    NaN      NaN   NaN
# 1445        NaN  Week 7                    NaN      NaN   NaN
# 1446        NaN  Week 7                    NaN      NaN   NaN
# 1447        NaN  Week 7                    NaN      NaN   NaN
# 1448        NaN  Week 7                    NaN      NaN   NaN
# 1449        NaN  Week 7                    NaN      NaN   NaN
# 1450        NaN  Week 7                    NaN      NaN   NaN
# 1451        NaN  Week 7                    NaN      NaN   NaN
# 1452        NaN  Week 5                    NaN      NaN   NaN
#
# [2445 rows x 19 columns]

# %% [markdown]
# ## Try: making just a 2016 table, getting it clean, THEN joining a 2017 table to it
